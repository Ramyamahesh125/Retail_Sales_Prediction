# %%
# Importing required packages:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import datetime as dt

# %%
# Reading feature data set:

feature_df = pd.read_csv(r"C:\Users\ramya\Downloads\Features_data_set.csv")
feature_df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
# Reading store data set:

store_df = pd.read_csv(r"C:\Users\ramya\Downloads\stores_data_set.csv")
store_df
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
# Reading sales dataset:

sales_df = pd.read_csv(r"C:\Users\ramya\Downloads\sales_data_set.csv")
sales_df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %% [markdown]
# ## Merging Dataframes

# %%
# Merging feature and store df based on "Store" key value:

df1 = pd.merge(feature_df, store_df, on = "Store", how = "inner")
df1
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
#      Type    Size
# 0       A  151315
# 1       A  151315
# 2       A  151315
# 3       A  151315
# 4       A  151315
# ...   ...     ...
# 8185    B  118221
# 8186    B  118221
# 8187    B  118221
# 8188    B  118221
# 8189    B  118221
#
# [8190 rows x 14 columns]

# %%
# Merging sales and store df :

df2 = pd.merge(sales_df, store_df, on = "Store", how = "inner")
df2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     1  12/02/2010      46039.49       True    A  151315
# 2           1     1  19/02/2010      41595.55      False    A  151315
# 3           1     1  26/02/2010      19403.54      False    A  151315
# 4           1     1  05/03/2010      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  28/09/2012        508.37      False    B  118221
# 421566     45    98  05/10/2012        628.10      False    B  118221
# 421567     45    98  12/10/2012       1061.02      False    B  118221
# 421568     45    98  19/10/2012        760.01      False    B  118221
# 421569     45    98  26/10/2012       1076.80      False    B  118221
#
# [421570 rows x 7 columns]

# %%
# df1 has 2010 to 2013 data,  df2 has 2010 to 2012 data
# so we have to separate df1's 2010 to 2012 data

# %%
# Creating "Differ" column for both df1 and df2 :

df1["Differ"] = df1["Store"].astype(str) + "-" + df1["Date"]
df2["Differ"] = df2["Store"].astype(str) + "-" + df2["Date"]

# %%
df1.head(2)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# 1        NaN        NaN        NaN  211.242170         8.106       True    A
#
#      Size        Differ
# 0  151315  1-05/02/2010
# 1  151315  1-12/02/2010

# %%
df2.head(2)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size        Differ
# 0      1     1  05/02/2010      24924.50      False    A  151315  1-05/02/2010
# 1      1     1  12/02/2010      46039.49       True    A  151315  1-12/02/2010

# %%
# Separating df1's value matched to value with df2 :

df1_inlist  = df1[df1["Differ"].isin(df2["Differ"])]
df1_inlist.reset_index(drop = True, inplace = True)
df1_inlist
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 6430     45  28/09/2012        64.88       3.997    4556.61      20.64
# 6431     45  05/10/2012        64.89       3.985    5046.74        NaN
# 6432     45  12/10/2012        54.47       4.000    1956.28        NaN
# 6433     45  19/10/2012        56.47       3.969    2004.02        NaN
# 6434     45  26/10/2012        58.85       3.882    4018.91      58.08
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 6430       1.50    1601.01    3288.25  192.013558         8.684      False
# 6431      18.82    2253.43    2340.01  192.170412         8.667      False
# 6432       7.89     599.32    3990.54  192.327265         8.667      False
# 6433       3.18     437.73    1537.49  192.330854         8.667      False
# 6434     100.00     211.94     858.33  192.308899         8.667      False
#
#      Type    Size         Differ
# 0       A  151315   1-05/02/2010
# 1       A  151315   1-12/02/2010
# 2       A  151315   1-19/02/2010
# 3       A  151315   1-26/02/2010
# 4       A  151315   1-05/03/2010
# ...   ...     ...            ...
# 6430    B  118221  45-28/09/2012
# 6431    B  118221  45-05/10/2012
# 6432    B  118221  45-12/10/2012
# 6433    B  118221  45-19/10/2012
# 6434    B  118221  45-26/10/2012
#
# [6435 rows x 15 columns]

# %%
# Separating df1's value not matched to df2:

df1_notinlist = df1[~df1["Differ"].isin(df2["Differ"])]
df1_notinlist.reset_index(drop = True, inplace = True)
df1_notinlist
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  02/11/2012        55.32       3.386    6766.44    5147.70
# 1         1  09/11/2012        61.24       3.314   11421.32    3370.89
# 2         1  16/11/2012        52.92       3.252    9696.28     292.10
# 3         1  23/11/2012        56.23       3.211     883.59       4.17
# 4         1  30/11/2012        52.34       3.207    2460.03        NaN
# ...     ...         ...          ...         ...        ...        ...
# 1750     45  28/06/2013        76.05       3.639    4842.29     975.03
# 1751     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 1752     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 1753     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 1754     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0         50.82    3639.90    2737.42  223.462779         6.573      False
# 1         40.28    4646.79    6154.16  223.481307         6.573      False
# 2        103.78    1133.15    6612.69  223.512911         6.573      False
# 3      74910.32     209.91     303.32  223.561947         6.573       True
# 4       3838.35     150.57    6966.34  223.610984         6.573      False
# ...         ...        ...        ...         ...           ...        ...
# 1750       3.00    2449.97    3169.69         NaN           NaN      False
# 1751     582.74    5797.47    1514.93         NaN           NaN      False
# 1752      85.72     744.84    2150.36         NaN           NaN      False
# 1753     204.19     363.00    1059.46         NaN           NaN      False
# 1754       2.06      10.88    1864.57         NaN           NaN      False
#
#      Type    Size         Differ
# 0       A  151315   1-02/11/2012
# 1       A  151315   1-09/11/2012
# 2       A  151315   1-16/11/2012
# 3       A  151315   1-23/11/2012
# 4       A  151315   1-30/11/2012
# ...   ...     ...            ...
# 1750    B  118221  45-28/06/2013
# 1751    B  118221  45-05/07/2013
# 1752    B  118221  45-12/07/2013
# 1753    B  118221  45-19/07/2013
# 1754    B  118221  45-26/07/2013
#
# [1755 rows x 15 columns]

# %% [markdown]
# ## Checking the Shape and Unique value

# %%
# Checking the shape:

df1.shape, df1_inlist.shape, df1_notinlist.shape
# Out:
# ((8190, 15), (6435, 15), (1755, 15))

# %%
# Checking the number of unique :

df1["Differ"].nunique(), df1_inlist["Differ"].nunique(), df1_notinlist["Differ"].nunique()
# Out:
# (8190, 6435, 1755)

# %%
#there are no duplicate value

# %%
# Merging the separated df1's 2010 to 2012 data with df2:

df3 = pd.merge(df2, df1_inlist, on = "Differ", how = "inner")
df3
# Out:
#         Store_x  Dept      Date_x  Weekly_Sales  IsHoliday_x Type_x  Size_x  \
# 0             1     1  05/02/2010      24924.50        False      A  151315
# 1             1     2  05/02/2010      50605.27        False      A  151315
# 2             1     3  05/02/2010      13740.12        False      A  151315
# 3             1     4  05/02/2010      39954.04        False      A  151315
# 4             1     5  05/02/2010      32229.38        False      A  151315
# ...         ...   ...         ...           ...          ...    ...     ...
# 421565       45    93  26/10/2012       2487.80        False      B  118221
# 421566       45    94  26/10/2012       5203.31        False      B  118221
# 421567       45    95  26/10/2012      56017.47        False      B  118221
# 421568       45    97  26/10/2012       6817.48        False      B  118221
# 421569       45    98  26/10/2012       1076.80        False      B  118221
#
#                Differ  Store_y      Date_y  ...  MarkDown1  MarkDown2  \
# 0        1-05/02/2010        1  05/02/2010  ...        NaN        NaN
# 1        1-05/02/2010        1  05/02/2010  ...        NaN        NaN
# 2        1-05/02/2010        1  05/02/2010  ...        NaN        NaN
# 3        1-05/02/2010        1  05/02/2010  ...        NaN        NaN
# 4        1-05/02/2010        1  05/02/2010  ...        NaN        NaN
# ...               ...      ...         ...  ...        ...        ...
# 421565  45-26/10/2012       45  26/10/2012  ...    4018.91      58.08
# 421566  45-26/10/2012       45  26/10/2012  ...    4018.91      58.08
# 421567  45-26/10/2012       45  26/10/2012  ...    4018.91      58.08
# 421568  45-26/10/2012       45  26/10/2012  ...    4018.91      58.08
# 421569  45-26/10/2012       45  26/10/2012  ...    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0             NaN        NaN        NaN  211.096358         8.106
# 1             NaN        NaN        NaN  211.096358         8.106
# 2             NaN        NaN        NaN  211.096358         8.106
# 3             NaN        NaN        NaN  211.096358         8.106
# 4             NaN        NaN        NaN  211.096358         8.106
# ...           ...        ...        ...         ...           ...
# 421565      100.0     211.94     858.33  192.308899         8.667
# 421566      100.0     211.94     858.33  192.308899         8.667
# 421567      100.0     211.94     858.33  192.308899         8.667
# 421568      100.0     211.94     858.33  192.308899         8.667
# 421569      100.0     211.94     858.33  192.308899         8.667
#
#         IsHoliday_y  Type_y  Size_y
# 0             False       A  151315
# 1             False       A  151315
# 2             False       A  151315
# 3             False       A  151315
# 4             False       A  151315
# ...             ...     ...     ...
# 421565        False       B  118221
# 421566        False       B  118221
# 421567        False       B  118221
# 421568        False       B  118221
# 421569        False       B  118221
#
# [421570 rows x 22 columns]

# %%
df3.columns
# Out:
# Index(['Store_x', 'Dept', 'Date_x', 'Weekly_Sales', 'IsHoliday_x', 'Type_x',
#        'Size_x', 'Differ', 'Store_y', 'Date_y', 'Temperature', 'Fuel_Price',
#        'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI',
#        'Unemployment', 'IsHoliday_y', 'Type_y', 'Size_y'],
#       dtype='object')

# %%
# Droping the duplicate column:

df3.drop(columns = ["Store_y", "Date_y", "IsHoliday_y", "Type_y", "Size_y"], inplace = True)

# %%
df3.columns
# Out:
# Index(['Store_x', 'Dept', 'Date_x', 'Weekly_Sales', 'IsHoliday_x', 'Type_x',
#        'Size_x', 'Differ', 'Temperature', 'Fuel_Price', 'MarkDown1',
#        'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI',
#        'Unemployment'],
#       dtype='object')

# %%
# Renaming the columns:

df3.rename(columns = {"Store_x":"Store", "Date_x":"Date", "IsHoliday_x":"IsHoliday", "Type_x":"Type", "Size_x":"Size"}, inplace = True)

# %%
df3.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Differ', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
# Now we want to merge df3 and df1_notinlist(2012 to 2013)
# But df3 has "Dept" column , df1_notinlist doesn't have
# So we want to add "Dept" column to df1_notinlist

# %%
# Selecting "Store","Dept" from sales data:
sd = sales_df[["Store", "Dept"]]
sd
# Out:
#         Store  Dept
# 0           1     1
# 1           1     1
# 2           1     1
# 3           1     1
# 4           1     1
# ...       ...   ...
# 421565     45    98
# 421566     45    98
# 421567     45    98
# 421568     45    98
# 421569     45    98
#
# [421570 rows x 2 columns]

# %%
# Droping duplicate values in sd:
sd.drop_duplicates(subset = ["Store", "Dept"], inplace = True)
sd.reset_index(drop = True, inplace = True)
sd
# Out:
#       Store  Dept
# 0         1     1
# 1         1     2
# 2         1     3
# 3         1     4
# 4         1     5
# ...     ...   ...
# 3326     45    94
# 3327     45    95
# 3328     45    96
# 3329     45    97
# 3330     45    98
#
# [3331 rows x 2 columns]

# %%
df1_notinlist
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  02/11/2012        55.32       3.386    6766.44    5147.70
# 1         1  09/11/2012        61.24       3.314   11421.32    3370.89
# 2         1  16/11/2012        52.92       3.252    9696.28     292.10
# 3         1  23/11/2012        56.23       3.211     883.59       4.17
# 4         1  30/11/2012        52.34       3.207    2460.03        NaN
# ...     ...         ...          ...         ...        ...        ...
# 1750     45  28/06/2013        76.05       3.639    4842.29     975.03
# 1751     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 1752     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 1753     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 1754     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0         50.82    3639.90    2737.42  223.462779         6.573      False
# 1         40.28    4646.79    6154.16  223.481307         6.573      False
# 2        103.78    1133.15    6612.69  223.512911         6.573      False
# 3      74910.32     209.91     303.32  223.561947         6.573       True
# 4       3838.35     150.57    6966.34  223.610984         6.573      False
# ...         ...        ...        ...         ...           ...        ...
# 1750       3.00    2449.97    3169.69         NaN           NaN      False
# 1751     582.74    5797.47    1514.93         NaN           NaN      False
# 1752      85.72     744.84    2150.36         NaN           NaN      False
# 1753     204.19     363.00    1059.46         NaN           NaN      False
# 1754       2.06      10.88    1864.57         NaN           NaN      False
#
#      Type    Size         Differ
# 0       A  151315   1-02/11/2012
# 1       A  151315   1-09/11/2012
# 2       A  151315   1-16/11/2012
# 3       A  151315   1-23/11/2012
# 4       A  151315   1-30/11/2012
# ...   ...     ...            ...
# 1750    B  118221  45-28/06/2013
# 1751    B  118221  45-05/07/2013
# 1752    B  118221  45-12/07/2013
# 1753    B  118221  45-19/07/2013
# 1754    B  118221  45-26/07/2013
#
# [1755 rows x 15 columns]

# %%
# Merging sd and df1_notinlist data:

df4 = pd.merge(sd, df1_notinlist, on = "Store", how = "outer")
df4
# Out:
#         Store  Dept        Date  Temperature  Fuel_Price  MarkDown1  \
# 0           1     1  02/11/2012        55.32       3.386    6766.44
# 1           1     1  09/11/2012        61.24       3.314   11421.32
# 2           1     1  16/11/2012        52.92       3.252    9696.28
# 3           1     1  23/11/2012        56.23       3.211     883.59
# 4           1     1  30/11/2012        52.34       3.207    2460.03
# ...       ...   ...         ...          ...         ...        ...
# 129904     45    98  28/06/2013        76.05       3.639    4842.29
# 129905     45    98  05/07/2013        77.50       3.614    9090.48
# 129906     45    98  12/07/2013        79.37       3.614    3789.94
# 129907     45    98  19/07/2013        82.84       3.737    2961.49
# 129908     45    98  26/07/2013        76.06       3.804     212.02
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0         5147.70      50.82    3639.90    2737.42  223.462779         6.573
# 1         3370.89      40.28    4646.79    6154.16  223.481307         6.573
# 2          292.10     103.78    1133.15    6612.69  223.512911         6.573
# 3            4.17   74910.32     209.91     303.32  223.561947         6.573
# 4             NaN    3838.35     150.57    6966.34  223.610984         6.573
# ...           ...        ...        ...        ...         ...           ...
# 129904     975.03       3.00    2449.97    3169.69         NaN           NaN
# 129905    2268.58     582.74    5797.47    1514.93         NaN           NaN
# 129906    1827.31      85.72     744.84    2150.36         NaN           NaN
# 129907    1047.07     204.19     363.00    1059.46         NaN           NaN
# 129908     851.73       2.06      10.88    1864.57         NaN           NaN
#
#         IsHoliday Type    Size         Differ
# 0           False    A  151315   1-02/11/2012
# 1           False    A  151315   1-09/11/2012
# 2           False    A  151315   1-16/11/2012
# 3            True    A  151315   1-23/11/2012
# 4           False    A  151315   1-30/11/2012
# ...           ...  ...     ...            ...
# 129904      False    B  118221  45-28/06/2013
# 129905      False    B  118221  45-05/07/2013
# 129906      False    B  118221  45-12/07/2013
# 129907      False    B  118221  45-19/07/2013
# 129908      False    B  118221  45-26/07/2013
#
# [129909 rows x 16 columns]

# %%
# Concating df3 and df4 df:

df5 = pd.concat([df3, df4])
df5.reset_index(drop = True, inplace = True)
df5
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     2  05/02/2010      50605.27      False    A  151315
# 2           1     3  05/02/2010      13740.12      False    A  151315
# 3           1     4  05/02/2010      39954.04      False    A  151315
# 4           1     5  05/02/2010      32229.38      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 551474     45    98  28/06/2013           NaN      False    B  118221
# 551475     45    98  05/07/2013           NaN      False    B  118221
# 551476     45    98  12/07/2013           NaN      False    B  118221
# 551477     45    98  19/07/2013           NaN      False    B  118221
# 551478     45    98  26/07/2013           NaN      False    B  118221
#
#                Differ  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0        1-05/02/2010        42.31       2.572        NaN        NaN
# 1        1-05/02/2010        42.31       2.572        NaN        NaN
# 2        1-05/02/2010        42.31       2.572        NaN        NaN
# 3        1-05/02/2010        42.31       2.572        NaN        NaN
# 4        1-05/02/2010        42.31       2.572        NaN        NaN
# ...               ...          ...         ...        ...        ...
# 551474  45-28/06/2013        76.05       3.639    4842.29     975.03
# 551475  45-05/07/2013        77.50       3.614    9090.48    2268.58
# 551476  45-12/07/2013        79.37       3.614    3789.94    1827.31
# 551477  45-19/07/2013        82.84       3.737    2961.49    1047.07
# 551478  45-26/07/2013        76.06       3.804     212.02     851.73
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment
# 0             NaN        NaN        NaN  211.096358         8.106
# 1             NaN        NaN        NaN  211.096358         8.106
# 2             NaN        NaN        NaN  211.096358         8.106
# 3             NaN        NaN        NaN  211.096358         8.106
# 4             NaN        NaN        NaN  211.096358         8.106
# ...           ...        ...        ...         ...           ...
# 551474       3.00    2449.97    3169.69         NaN           NaN
# 551475     582.74    5797.47    1514.93         NaN           NaN
# 551476      85.72     744.84    2150.36         NaN           NaN
# 551477     204.19     363.00    1059.46         NaN           NaN
# 551478       2.06      10.88    1864.57         NaN           NaN
#
# [551479 rows x 17 columns]

# %%
# replacing the character to change into datetime format:

df5["Date"] = df5["Date"].apply(lambda x : x.replace("/","-"))
df5["Date"]
# Out:
# 0         05-02-2010
# 1         05-02-2010
# 2         05-02-2010
# 3         05-02-2010
# 4         05-02-2010
#              ...
# 551474    28-06-2013
# 551475    05-07-2013
# 551476    12-07-2013
# 551477    19-07-2013
# 551478    26-07-2013
# Name: Date, Length: 551479, dtype: object

# %%
# changing the format into datetime for "Date":

df5["Date"] = pd.to_datetime(df5["Date"], format= "%d-%m-%Y", errors = "coerce")

# %%
# Mapping the value:

df5["IsHoliday"] = df5["IsHoliday"].map({False : 0, True : 1})

df5["Type"]  = df5["Type"].map({"A":0, "B":1, "C":2})

# %%
df5
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Type    Size  \
# 0           1     1 2010-02-05      24924.50          0     0  151315
# 1           1     2 2010-02-05      50605.27          0     0  151315
# 2           1     3 2010-02-05      13740.12          0     0  151315
# 3           1     4 2010-02-05      39954.04          0     0  151315
# 4           1     5 2010-02-05      32229.38          0     0  151315
# ...       ...   ...        ...           ...        ...   ...     ...
# 551474     45    98 2013-06-28           NaN          0     1  118221
# 551475     45    98 2013-07-05           NaN          0     1  118221
# 551476     45    98 2013-07-12           NaN          0     1  118221
# 551477     45    98 2013-07-19           NaN          0     1  118221
# 551478     45    98 2013-07-26           NaN          0     1  118221
#
#                Differ  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0        1-05/02/2010        42.31       2.572        NaN        NaN
# 1        1-05/02/2010        42.31       2.572        NaN        NaN
# 2        1-05/02/2010        42.31       2.572        NaN        NaN
# 3        1-05/02/2010        42.31       2.572        NaN        NaN
# 4        1-05/02/2010        42.31       2.572        NaN        NaN
# ...               ...          ...         ...        ...        ...
# 551474  45-28/06/2013        76.05       3.639    4842.29     975.03
# 551475  45-05/07/2013        77.50       3.614    9090.48    2268.58
# 551476  45-12/07/2013        79.37       3.614    3789.94    1827.31
# 551477  45-19/07/2013        82.84       3.737    2961.49    1047.07
# 551478  45-26/07/2013        76.06       3.804     212.02     851.73
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment
# 0             NaN        NaN        NaN  211.096358         8.106
# 1             NaN        NaN        NaN  211.096358         8.106
# 2             NaN        NaN        NaN  211.096358         8.106
# 3             NaN        NaN        NaN  211.096358         8.106
# 4             NaN        NaN        NaN  211.096358         8.106
# ...           ...        ...        ...         ...           ...
# 551474       3.00    2449.97    3169.69         NaN           NaN
# 551475     582.74    5797.47    1514.93         NaN           NaN
# 551476      85.72     744.84    2150.36         NaN           NaN
# 551477     204.19     363.00    1059.46         NaN           NaN
# 551478       2.06      10.88    1864.57         NaN           NaN
#
# [551479 rows x 17 columns]

# %%
#Dropping the unwanted column "Differ":

df5.drop(columns = ["Differ"], inplace = True)

# %%
# Sorting values based od "Date","Store", "Dept":

df5.sort_values(by = ["Store", "Dept", "Date"], inplace = True)
df5.reset_index(drop = True, inplace = True)
df5
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Type    Size  \
# 0           1     1 2010-02-05      24924.50          0     0  151315
# 1           1     1 2010-02-12      46039.49          1     0  151315
# 2           1     1 2010-02-19      41595.55          0     0  151315
# 3           1     1 2010-02-26      19403.54          0     0  151315
# 4           1     1 2010-03-05      21827.90          0     0  151315
# ...       ...   ...        ...           ...        ...   ...     ...
# 551474     45    98 2013-06-28           NaN          0     1  118221
# 551475     45    98 2013-07-05           NaN          0     1  118221
# 551476     45    98 2013-07-12           NaN          0     1  118221
# 551477     45    98 2013-07-19           NaN          0     1  118221
# 551478     45    98 2013-07-26           NaN          0     1  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             38.51       2.548        NaN        NaN        NaN        NaN
# 2             39.93       2.514        NaN        NaN        NaN        NaN
# 3             46.63       2.561        NaN        NaN        NaN        NaN
# 4             46.50       2.625        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 551474        76.05       3.639    4842.29     975.03       3.00    2449.97
# 551475        77.50       3.614    9090.48    2268.58     582.74    5797.47
# 551476        79.37       3.614    3789.94    1827.31      85.72     744.84
# 551477        82.84       3.737    2961.49    1047.07     204.19     363.00
# 551478        76.06       3.804     212.02     851.73       2.06      10.88
#
#         MarkDown5         CPI  Unemployment
# 0             NaN  211.096358         8.106
# 1             NaN  211.242170         8.106
# 2             NaN  211.289143         8.106
# 3             NaN  211.319643         8.106
# 4             NaN  211.350143         8.106
# ...           ...         ...           ...
# 551474    3169.69         NaN           NaN
# 551475    1514.93         NaN           NaN
# 551476    2150.36         NaN           NaN
# 551477    1059.46         NaN           NaN
# 551478    1864.57         NaN           NaN
#
# [551479 rows x 16 columns]

# %%
# Separating day, month, year from "Date" column:

df5["Day"] = df5["Date"].dt.day

df5["Month"] = df5["Date"].dt.month

df5["Year"] = df5["Date"].dt.year

# %%
# Dropping the unwanted column:

df5.drop(columns = ["Date"], inplace = True)

# %%
df5.columns
# Out:
# Index(['Store', 'Dept', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Day', 'Month',
#        'Year'],
#       dtype='object')

# %%
# Changing the order of the df:
df5 = df5[["Day", "Month", "Year", "Store", "Dept", "Type", "Weekly_Sales", "Size", "IsHoliday", "Temperature", "Fuel_Price",
           "MarkDown1", "MarkDown2", "MarkDown3", "MarkDown4", "MarkDown5", "CPI", "Unemployment"]]

# %%
df5.describe()
# Out:
#                  Day          Month           Year          Store  \
# count  551479.000000  551479.000000  551479.000000  551479.000000
# mean       15.653488       6.277180    2011.392758      22.270485
# std         8.776044       3.340134       1.054086      12.796872
# min         1.000000       1.000000    2010.000000       1.000000
# 25%         8.000000       3.000000    2010.000000      11.000000
# 50%        16.000000       6.000000    2011.000000      22.000000
# 75%        23.000000       9.000000    2012.000000      33.000000
# max        31.000000      12.000000    2013.000000      45.000000
#
#                 Dept           Type   Weekly_Sales           Size  \
# count  551479.000000  551479.000000  421570.000000  551479.000000
# mean       44.603013       0.594791   15981.258123  136073.691863
# std        30.416079       0.669624   22711.183519   61207.331445
# min         1.000000       0.000000   -4988.940000   34875.000000
# 25%        19.000000       0.000000    2079.650000   93638.000000
# 50%        38.000000       0.000000    7612.030000  128107.000000
# 75%        74.000000       1.000000   20205.852500  202505.000000
# max        99.000000       2.000000  693099.360000  219622.000000
#
#            IsHoliday    Temperature     Fuel_Price      MarkDown1  \
# count  551479.000000  551479.000000  551479.000000  280405.000000
# mean        0.071905      58.703624       3.413010    7369.403469
# std         0.258330      18.685408       0.427725    9439.253385
# min         0.000000      -7.290000       2.472000   -2781.450000
# 25%         0.000000      45.160000       3.050000    2014.470000
# 50%         0.000000      59.940000       3.524000    5011.720000
# 75%         0.000000      73.160000       3.746000    9264.480000
# max         1.000000     101.950000       4.468000  103184.980000
#
#            MarkDown2      MarkDown3      MarkDown4      MarkDown5  \
# count  207897.000000  254619.000000  248649.000000  281341.000000
# mean     3489.575965    1859.728572    3355.891061    4261.631495
# std      8920.862286   11633.662079    6889.409946   13679.851274
# min      -265.760000    -179.260000       0.220000    -185.170000
# 25%        74.240000       7.330000     319.190000    1524.870000
# 50%       397.960000      41.390000    1202.440000    2825.360000
# 75%      2359.440000     177.270000    3380.280000    4930.020000
# max    104519.540000  149483.310000   67474.850000  771448.100000
#
#                  CPI   Unemployment
# count  508176.000000  508176.000000
# mean      172.200115       7.775470
# std        39.595683       1.863253
# min       126.064000       3.684000
# 25%       132.529129       6.614000
# 50%       182.517732       7.771000
# 75%       213.871114       8.549000
# max       228.976456      14.313000

# %%
# Weekly sales have negative values
# so we want to change the negative values into null values:

# %%
df5[df5["Weekly_Sales"]<= 0]
# Out:
#         Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 1041     10      8  2012      1     6     0       -139.65  151315          0
# 3008      4      5  2012      1    18     0         -1.27  151315          0
# 7725     19      2  2010      1    47     0       -863.00  151315          0
# 7726     12      3  2010      1    47     0       -698.00  151315          0
# 7728      8     10  2010      1    47     0        -58.00  151315          0
# ...     ...    ...   ...    ...   ...   ...           ...     ...        ...
# 548921   12      2  2010     45    80     1         -0.43  118221          1
# 548922   19      2  2010     45    80     1         -0.27  118221          0
# 548927   16      4  2010     45    80     1         -1.61  118221          0
# 548938    2      7  2010     45    80     1         -0.27  118221          0
# 548964   11      2  2011     45    80     1         -0.24  118221          1
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 1041          85.05       3.494   11436.22      245.0       6.85    6964.26
# 3008          75.55       3.749   21290.13        NaN      69.89    4977.35
# 7725          39.93       2.514        NaN        NaN        NaN        NaN
# 7726          57.79       2.667        NaN        NaN        NaN        NaN
# 7728          63.93       2.633        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 548921        27.73       2.773        NaN        NaN        NaN        NaN
# 548922        31.27       2.745        NaN        NaN        NaN        NaN
# 548927        54.28       2.899        NaN        NaN        NaN        NaN
# 548938        76.61       2.815        NaN        NaN        NaN        NaN
# 548964        30.30       3.239        NaN        NaN        NaN        NaN
#
#         MarkDown5         CPI  Unemployment
# 1041      4836.22  221.958433         6.908
# 3008      3261.04  221.671800         7.143
# 7725          NaN  211.289143         8.106
# 7726          NaN  211.380643         8.106
# 7728          NaN  211.746754         7.838
# ...           ...         ...           ...
# 548921        NaN  181.982317         8.992
# 548922        NaN  182.034782         8.992
# 548927        NaN  181.692477         8.899
# 548938        NaN  182.318780         8.743
# 548964        NaN  183.701613         8.549
#
# [1358 rows x 18 columns]

# %%
# converting negative values into NaN:

df5["Weekly_Sales"] = df5["Weekly_Sales"].apply(lambda x : np.nan if x<=0 else x)

# %%
df5.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       271074
# MarkDown2       343582
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# dtype: int64

# %%
# Creating new column "MarkDown" and converting those value into boolean :

df5["MarkDown"] =  df5[["MarkDown1", "MarkDown2", "MarkDown3", "MarkDown4", "MarkDown5"]].notnull().any(axis = 1)

# %%
# Mapping the int value:

df5["MarkDown"] = df5["MarkDown"].map({False:0, True:1})

# %%
df5["MarkDown"].isnull().sum()
# Out:
# 0

# %%
# Checking "Weekly_Sales" based on  grouping with MarkDown:

df5.groupby("MarkDown")["Weekly_Sales"].mean()
# Out:
# MarkDown
# 0    15922.137810
# 1    16231.116041
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# ## Correlation:

# %%
df5_corr = df5.corr()

# %%
# Checking the correlation by using "heatmap":

plt.figure(figsize = (15,8))
sns.heatmap(df5_corr, annot = True, cmap = "coolwarm", fmt = ".2f" )
plt.show()

# %%
# Removing null values:
df5_dropna = df5.dropna()

# %%
df5_dropna_corr = df5_dropna.corr()

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df5_dropna_corr, annot = True, cmap = "coolwarm", fmt = ".2f")
plt.show()

# %%
# Weekly_Sales have high correlation with "Size", "Type" and "Dept"

# %%
# Creating column "Differ" by combining other columns

df5["Differ"] = df5["Day"].astype(str) + df5["Month"].astype(str) + df5["Year"].astype(str) +"-"+ df5["Store"].astype(str) +"-"+ df5["Dept"].astype(str)

# %%
df5["Differ"]
# Out:
# 0            522010-1-1
# 1           1222010-1-1
# 2           1922010-1-1
# 3           2622010-1-1
# 4            532010-1-1
#               ...
# 551474    2862013-45-98
# 551475     572013-45-98
# 551476    1272013-45-98
# 551477    1972013-45-98
# 551478    2672013-45-98
# Name: Differ, Length: 551479, dtype: object

# %%
df5.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       271074
# MarkDown2       343582
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# MarkDown             0
# Differ               0
# dtype: int64

# %%
# MarkDown have more null values than other columns

# %%
# Importing required packages for ML:

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
import pickle

# %%
df5_m1 = df5.copy()
df5_m1.drop(columns = ["MarkDown"], inplace = True)
df5_m1.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       271074
# MarkDown2       343582
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# Differ               0
# dtype: int64

# %%
df5_m1.head()
# Out:
#    Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0    5      2  2010      1     1     0      24924.50  151315          0
# 1   12      2  2010      1     1     0      46039.49  151315          1
# 2   19      2  2010      1     1     0      41595.55  151315          0
# 3   26      2  2010      1     1     0      19403.54  151315          0
# 4    5      3  2010      1     1     0      21827.90  151315          0
#
#    Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0        42.31       2.572        NaN        NaN        NaN        NaN
# 1        38.51       2.548        NaN        NaN        NaN        NaN
# 2        39.93       2.514        NaN        NaN        NaN        NaN
# 3        46.63       2.561        NaN        NaN        NaN        NaN
# 4        46.50       2.625        NaN        NaN        NaN        NaN
#
#    MarkDown5         CPI  Unemployment       Differ
# 0        NaN  211.096358         8.106   522010-1-1
# 1        NaN  211.242170         8.106  1222010-1-1
# 2        NaN  211.289143         8.106  1922010-1-1
# 3        NaN  211.319643         8.106  2622010-1-1
# 4        NaN  211.350143         8.106   532010-1-1

# %%
# Function for choosing best algorithm by R2 Score:

def accuracy_score(df,algorithm):
    
    x = df.drop(columns = ["Weekly_Sales","Differ"]).fillna(0)
    y = df["Weekly_Sales"].fillna(0)
    x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.2, random_state = 42)
    
    model=algorithm().fit(x_train,y_train)
    y_pred_train= model.predict(x_train)
    y_pred_test= model.predict(x_test)

    r2_score_train=r2_score(y_pred_train,y_train)
    r2_score_test= r2_score(y_pred_test,y_test)

    accuracy={"algorithm":algorithm,
              "R2_train":r2_score_train,
              "R2_test":r2_score_test}
    
    return accuracy

# %%
accuracy_score(df5_m1, RandomForestRegressor)
# Out:
# {'algorithm': sklearn.ensemble._forest.RandomForestRegressor,
#  'R2_train': 0.9960336206312689,
#  'R2_test': 0.9747903751603704}

# %%
accuracy_score(df5_m1, ExtraTreesRegressor)
# Out:
# {'algorithm': sklearn.ensemble._forest.ExtraTreesRegressor,
#  'R2_train': 0.9999999999983319,
#  'R2_test': 0.9790488820531534}

# %%
accuracy_score(df5_m1, DecisionTreeRegressor)
# Out:
# {'algorithm': sklearn.tree._classes.DecisionTreeRegressor,
#  'R2_train': 1.0,
#  'R2_test': 0.9563300796114957}

# %%
accuracy_score(df5_m1, AdaBoostRegressor)
# Out:
# {'algorithm': sklearn.ensemble._weight_boosting.AdaBoostRegressor,
#  'R2_train': -1.4700278355543772,
#  'R2_test': -1.524712069286256}

# %%
accuracy_score(df5_m1, GradientBoostingRegressor)
# Out:
# {'algorithm': sklearn.ensemble._gb.GradientBoostingRegressor,
#  'R2_train': 0.24750536423601577,
#  'R2_test': 0.25619434405431873}

# %%
accuracy_score(df5_m1, XGBRegressor)
# Out:
# {'algorithm': xgboost.sklearn.XGBRegressor,
#  'R2_train': 0.9089166964352795,
#  'R2_test': 0.9072613820815145}

# %%
# I choose RandomForestRegressor based on r2 score of both train and test data and also for its interpretability and robustness

# %%
# Function using Random Forest Regressor:

def RandomForest(df, null_columns, lable):

    # dropping null columns 
    df1 = df.drop(columns = null_columns)

    # Separating null columns for lable:
    df1_null = df1[df1[lable].isnull()]
    df1_null.reset_index(drop = True, inplace = True)

    # separating Not Null columns for lable:
    df1_notnull = df1[df1[lable].notnull()]
    df1_notnull.reset_index(drop = True, inplace =True)

    # choosing x and y value from notnull dataframe:
    x = df1_notnull.drop(columns = [lable, "Differ"])
    y = df1_notnull[lable]

    # Train test splitting:
    x_train, x_test, y_train, y_test = train_test_split(x,y , test_size = 0.2, random_state = 42)

    model = RandomForestRegressor().fit(x_train, y_train)
    y_pred = model.predict(x_test)

    # evaluating the model:
    mse = mean_squared_error(y_pred, y_test)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_pred, y_test)
    r2 = r2_score(y_pred, y_test)

    metrics = {"Mean Squared Error": mse,
               "Root Mean Squared Error": rmse,
               "Mean Absolute Error": mae,
               "R2 Score": r2}
    print(metrics)
    # predict the null values for the df1_null df:
    test_data = df1_null.drop(columns = [lable,"Differ"])
    y_pred_null_df = model.predict(test_data)

    df1_null[lable] = pd.DataFrame(y_pred_null_df)

    df_result = pd.concat([df1_null, df1_notnull], axis = 0, ignore_index= True)

    return df_result

# %%
df5_m1.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       271074
# MarkDown2       343582
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# Differ               0
# dtype: int64

# %%
df5_m1.columns
# Out:
# Index(['Day', 'Month', 'Year', 'Store', 'Dept', 'Type', 'Weekly_Sales', 'Size',
#        'IsHoliday', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Differ'],
#       dtype='object')

# %%
df5_m1_md1 = RandomForest(df5_m1,["Weekly_Sales","MarkDown2","MarkDown3","MarkDown4","MarkDown5","CPI","Unemployment"],"MarkDown1")
# Out:
# {'Mean Squared Error': 2.357807233864516, 'Root Mean Squared Error': 1.5355152991307237, 'Mean Absolute Error': 0.02783271697209903, 'R2 Score': 0.9999999730470549}

# %%
df5_m1_md2 = RandomForest(df5_m1,["Weekly_Sales","MarkDown1","MarkDown3","MarkDown4","MarkDown5","CPI","Unemployment"],"MarkDown2")
# Out:
# {'Mean Squared Error': 1.6541423135433734e-22, 'Root Mean Squared Error': 1.2861346405191696e-11, 'Mean Absolute Error': 4.052874682066388e-12, 'R2 Score': 1.0}

# %%
df5_m1_md3 = RandomForest(df5_m1,["Weekly_Sales","MarkDown1","MarkDown2","MarkDown4","MarkDown5","CPI","Unemployment"],"MarkDown3")
# Out:
# {'Mean Squared Error': 0.0008719846777550207, 'Root Mean Squared Error': 0.029529386680983077, 'Mean Absolute Error': 0.0007117096086902696, 'R2 Score': 0.999999999993636}

# %%
df5_m1_md4 = RandomForest(df5_m1,["Weekly_Sales","MarkDown1","MarkDown2","MarkDown3","MarkDown5","CPI","Unemployment"],"MarkDown4")
# Out:
# {'Mean Squared Error': 0.03312259734042884, 'Root Mean Squared Error': 0.18199614649884444, 'Mean Absolute Error': 0.0041646450874886125, 'R2 Score': 0.999999999294147}

# %%
df5_m1_md5 = RandomForest(df5_m1,["Weekly_Sales","MarkDown1","MarkDown2","MarkDown3","MarkDown4","CPI","Unemployment"],"MarkDown5")
# Out:
# {'Mean Squared Error': 6.996077771139837e-23, 'Root Mean Squared Error': 8.364255956831926e-12, 'Mean Absolute Error': 4.824084870079846e-12, 'R2 Score': 1.0}

# %%
df5_m1_MD = df5_m1.drop(columns = ["MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5"],axis = 1)
df5_m1_MD.head(3)
# Out:
#    Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0    5      2  2010      1     1     0      24924.50  151315          0
# 1   12      2  2010      1     1     0      46039.49  151315          1
# 2   19      2  2010      1     1     0      41595.55  151315          0
#
#    Temperature  Fuel_Price         CPI  Unemployment       Differ
# 0        42.31       2.572  211.096358         8.106   522010-1-1
# 1        38.51       2.548  211.242170         8.106  1222010-1-1
# 2        39.93       2.514  211.289143         8.106  1922010-1-1

# %%
df5_m1_md5.isnull().sum()
# Out:
# Day            0
# Month          0
# Year           0
# Store          0
# Dept           0
# Type           0
# Size           0
# IsHoliday      0
# Temperature    0
# Fuel_Price     0
# MarkDown5      0
# Differ         0
# dtype: int64

# %%
df5_m1_MD = pd.merge(df5_m1_MD,df5_m1_md1[["MarkDown1","Differ"]], on = "Differ",how = "inner")
df5_m1_MD = pd.merge(df5_m1_MD,df5_m1_md2[["MarkDown2","Differ"]], on = "Differ",how = "inner")
df5_m1_MD = pd.merge(df5_m1_MD,df5_m1_md3[["MarkDown3","Differ"]], on = "Differ",how = "inner")
df5_m1_MD = pd.merge(df5_m1_MD,df5_m1_md4[["MarkDown4","Differ"]], on = "Differ",how = "inner")
df5_m1_MD = pd.merge(df5_m1_MD,df5_m1_md5[["MarkDown5","Differ"]], on = "Differ",how = "inner")

# %%
df5_m1_MD
# Out:
#         Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0         5      2  2010      1     1     0      24924.50  151315          0
# 1        12      2  2010      1     1     0      46039.49  151315          1
# 2        19      2  2010      1     1     0      41595.55  151315          0
# 3        26      2  2010      1     1     0      19403.54  151315          0
# 4         5      3  2010      1     1     0      21827.90  151315          0
# ...     ...    ...   ...    ...   ...   ...           ...     ...        ...
# 551474   28      6  2013     45    98     1           NaN  118221          0
# 551475    5      7  2013     45    98     1           NaN  118221          0
# 551476   12      7  2013     45    98     1           NaN  118221          0
# 551477   19      7  2013     45    98     1           NaN  118221          0
# 551478   26      7  2013     45    98     1           NaN  118221          0
#
#         Temperature  Fuel_Price         CPI  Unemployment         Differ  \
# 0             42.31       2.572  211.096358         8.106     522010-1-1
# 1             38.51       2.548  211.242170         8.106    1222010-1-1
# 2             39.93       2.514  211.289143         8.106    1922010-1-1
# 3             46.63       2.561  211.319643         8.106    2622010-1-1
# 4             46.50       2.625  211.350143         8.106     532010-1-1
# ...             ...         ...         ...           ...            ...
# 551474        76.05       3.639         NaN           NaN  2862013-45-98
# 551475        77.50       3.614         NaN           NaN   572013-45-98
# 551476        79.37       3.614         NaN           NaN  1272013-45-98
# 551477        82.84       3.737         NaN           NaN  1972013-45-98
# 551478        76.06       3.804         NaN           NaN  2672013-45-98
#
#          MarkDown1   MarkDown2  MarkDown3   MarkDown4  MarkDown5
# 0        4817.6806   6381.0874   518.8603  25713.8268  4193.9831
# 1       61020.2785   6381.0874   101.2123  10455.3760  4106.0534
# 2       49856.4594  13078.3255    36.8538   8930.1488  4000.6223
# 3       49728.0249  12035.8679   330.5219   2998.1644  4964.5068
# 4        7309.9219   1770.9343   494.4015  25150.2929  6007.1121
# ...            ...         ...        ...         ...        ...
# 551474   4842.2900    975.0300     3.0000   2449.9700  3169.6900
# 551475   9090.4800   2268.5800   582.7400   5797.4700  1514.9300
# 551476   3789.9400   1827.3100    85.7200    744.8400  2150.3600
# 551477   2961.4900   1047.0700   204.1900    363.0000  1059.4600
# 551478    212.0200    851.7300     2.0600     10.8800  1864.5700
#
# [551479 rows x 19 columns]

# %%
df5_m1_MD.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# CPI              43303
# Unemployment     43303
# Differ               0
# MarkDown1            0
# MarkDown2            0
# MarkDown3            0
# MarkDown4            0
# MarkDown5            0
# dtype: int64

# %%
df5_m1_cpi = RandomForest(df5_m1_MD,["Weekly_Sales","Unemployment"],"CPI")
# Out:
# {'Mean Squared Error': 1.2345347025208194e-16, 'Root Mean Squared Error': 1.1110961715894891e-08, 'Mean Absolute Error': 2.1601107556565867e-10, 'R2 Score': 1.0}

# %%
df5_m1_CPI = df5_m1_MD.drop(columns = ["CPI"])

# %%
df5_m1_MDC = pd.merge(df5_m1_CPI,df5_m1_cpi[["CPI","Differ"]], on ="Differ", how = "inner")

# %%
df5_m1_MDC.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# Unemployment     43303
# Differ               0
# MarkDown1            0
# MarkDown2            0
# MarkDown3            0
# MarkDown4            0
# MarkDown5            0
# CPI                  0
# dtype: int64

# %%
df5_m1_unemp = RandomForest(df5_m1_MDC,["Weekly_Sales"],"Unemployment")
# Out:
# {'Mean Squared Error': 9.128070987833914e-28, 'Root Mean Squared Error': 3.0212697641610745e-14, 'Mean Absolute Error': 2.1456028867232485e-14, 'R2 Score': 1.0}

# %%
df5_m1_UNEMP = df5_m1_MDC.drop(columns = ["Unemployment"])

# %%
df5_m1_MDCU = pd.merge(df5_m1_UNEMP,df5_m1_unemp[["Unemployment","Differ"]],on = "Differ",how = "inner")

# %%
df5_m1_MDCU.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# Differ               0
# MarkDown1            0
# MarkDown2            0
# MarkDown3            0
# MarkDown4            0
# MarkDown5            0
# CPI                  0
# Unemployment         0
# dtype: int64

# %%
df5_m1_ws = RandomForest(df5_m1_MDCU,[],"Weekly_Sales")
# Out:
# {'Mean Squared Error': 12321430.116309525, 'Root Mean Squared Error': 3510.1894701439587, 'Mean Absolute Error': 1428.205729013719, 'R2 Score': 0.9750439160052669}

# %%
df5_m1_ws
# Out:
#         Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0         2     11  2012      1     1     0    27601.4460  151315          0
# 1         9     11  2012      1     1     0    23644.0426  151315          0
# 2        16     11  2012      1     1     0    19758.4872  151315          0
# 3        23     11  2012      1     1     0    24322.0565  151315          1
# 4        30     11  2012      1     1     0    45558.9581  151315          0
# ...     ...    ...   ...    ...   ...   ...           ...     ...        ...
# 551474   28      9  2012     45    98     1      508.3700  118221          0
# 551475    5     10  2012     45    98     1      628.1000  118221          0
# 551476   12     10  2012     45    98     1     1061.0200  118221          0
# 551477   19     10  2012     45    98     1      760.0100  118221          0
# 551478   26     10  2012     45    98     1     1076.8000  118221          0
#
#         Temperature  Fuel_Price          Differ  MarkDown1   MarkDown2  \
# 0             55.32       3.386     2112012-1-1    6766.44   5147.7000
# 1             61.24       3.314     9112012-1-1   11421.32   3370.8900
# 2             52.92       3.252    16112012-1-1    9696.28    292.1000
# 3             56.23       3.211    23112012-1-1     883.59      4.1700
# 4             52.34       3.207    30112012-1-1    2460.03  21441.2501
# ...             ...         ...             ...        ...         ...
# 551474        64.88       3.997   2892012-45-98    4556.61     20.6400
# 551475        64.89       3.985   5102012-45-98    5046.74    151.1404
# 551476        54.47       4.000  12102012-45-98    1956.28   9920.2501
# 551477        56.47       3.969  19102012-45-98    2004.02     97.5668
# 551478        58.85       3.882  26102012-45-98    4018.91     58.0800
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment
# 0           50.82    3639.90    2737.42  223.462779         6.573
# 1           40.28    4646.79    6154.16  223.481307         6.573
# 2          103.78    1133.15    6612.69  223.512911         6.573
# 3        74910.32     209.91     303.32  223.561947         6.573
# 4         3838.35     150.57    6966.34  223.610984         6.573
# ...           ...        ...        ...         ...           ...
# 551474       1.50    1601.01    3288.25  192.013558         8.684
# 551475      18.82    2253.43    2340.01  192.170412         8.667
# 551476       7.89     599.32    3990.54  192.327265         8.667
# 551477       3.18     437.73    1537.49  192.330854         8.667
# 551478     100.00     211.94     858.33  192.308899         8.667
#
# [551479 rows x 19 columns]

# %%
df5_m1_ws.isnull().sum()
# Out:
# Day             0
# Month           0
# Year            0
# Store           0
# Dept            0
# Type            0
# Weekly_Sales    0
# Size            0
# IsHoliday       0
# Temperature     0
# Fuel_Price      0
# Differ          0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df5_m1_MDCUW = df5_m1_ws.copy()

# %%
# Creating a new column of "Customer" by using weekly sales and cpi

# %%
df5_m1_MDCUW["Customer"] = df5_m1_MDCUW["Weekly_Sales"] / df5_m1_MDCUW["CPI"]

# %%
df5_m1_MDCUWC = df5_m1_MDCUW.copy()

# %%
#df5_m1_MDCUWC.to_csv("Final_M1.csv", index = False)

# %%
df5_m1_MDCUWC.head()
# Out:
#    Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0    2     11  2012      1     1     0    27601.4460  151315          0
# 1    9     11  2012      1     1     0    23644.0426  151315          0
# 2   16     11  2012      1     1     0    19758.4872  151315          0
# 3   23     11  2012      1     1     0    24322.0565  151315          1
# 4   30     11  2012      1     1     0    45558.9581  151315          0
#
#    Temperature  Fuel_Price        Differ  MarkDown1   MarkDown2  MarkDown3  \
# 0        55.32       3.386   2112012-1-1    6766.44   5147.7000      50.82
# 1        61.24       3.314   9112012-1-1   11421.32   3370.8900      40.28
# 2        52.92       3.252  16112012-1-1    9696.28    292.1000     103.78
# 3        56.23       3.211  23112012-1-1     883.59      4.1700   74910.32
# 4        52.34       3.207  30112012-1-1    2460.03  21441.2501    3838.35
#
#    MarkDown4  MarkDown5         CPI  Unemployment    Customer
# 0    3639.90    2737.42  223.462779         6.573  123.516973
# 1    4646.79    6154.16  223.481307         6.573  105.798748
# 2    1133.15    6612.69  223.512911         6.573   88.399758
# 3     209.91     303.32  223.561947         6.573  108.793365
# 4     150.57    6966.34  223.610984         6.573  203.742040

# %%
df_m1 = pd.read_csv(r"C:\Users\ramya\Final_M1.csv")

# %%
df_M1 = pd.merge(df5_m1_MDCU,df_m1[["Customer","Differ"]], on ="Differ", how = "inner")

# %%
df_M1.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# Weekly_Sales    131267
# Size                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# Differ               0
# MarkDown1            0
# MarkDown2            0
# MarkDown3            0
# MarkDown4            0
# MarkDown5            0
# CPI                  0
# Unemployment         0
# Customer             0
# dtype: int64

# %%
#df_M1.to_csv("Final_Model1.csv", index = False)

# %%
# Now we have a proper dataframe 
# Checking correlation for this dataframe

df_M1_corr = df_M1.drop(columns = ["Differ"]).corr()
plt.figure(figsize = (15,8))
sns.heatmap(df_M1_corr, annot = True, cmap = "Blues", fmt = ".2f")
plt.show()

# %%
df_M1 = pd.read_csv(r"C:\Users\ramya\Final_Model1.csv")

# %%
# Separating null values:
df_M1_null = df_M1[df_M1["Weekly_Sales"].isnull()]
df_M1_null.reset_index(drop = True, inplace = True)

# separating not null values:
df_M1_notnull = df_M1[df_M1["Weekly_Sales"].notnull()]
df_M1_notnull.reset_index(drop = True, inplace = True)

# Choosing x and y value from not null dataframe:
x = df_M1_notnull.drop(columns = ["Weekly_Sales","Differ"])
y = df_M1_notnull["Weekly_Sales"]

#Train test splitting
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

model1 = RandomForestRegressor().fit(x_train, y_train)
y_pred = model1.predict(x_test)

mse = mean_squared_error(y_pred, y_test)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_pred, y_test)
r2 = r2_score(y_pred, y_test)

metrics = {"Mean Squared Error" : mse,
           "Root Mean Squared Error": rmse,
           "Mean Absolute Error": mae,
           "R2 Score": r2}
print(metrics)
# Out:
# {'Mean Squared Error': 58165.25920150264, 'Root Mean Squared Error': 241.1747482666928, 'Mean Absolute Error': 22.308032597598835, 'R2 Score': 0.9998861851211487}

# %%
y_pred1 = model1.predict(np.array([[5,2,2010,1,1,0,151315,0,42.31,2.572,6707.7404,7098.0724,148.4776,15135.2254,4855.9997,211.096358,8.106,118.071672]]))
y_pred1[0]
# Out:
# 24935.189299999987

# %%
#with open(r"Final_ML_Model_1.pkl","wb") as a:
    #pickle.dump(model1,a)

# %% [markdown]
# ## Without Markdown Column : Model 2

# %%
df5_m2 = df5.copy()

# %%
df5_m2.drop(columns = ["MarkDown","MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5"],inplace = True)

# %%
df5_m2
# Out:
#         Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0         5      2  2010      1     1     0      24924.50  151315          0
# 1        12      2  2010      1     1     0      46039.49  151315          1
# 2        19      2  2010      1     1     0      41595.55  151315          0
# 3        26      2  2010      1     1     0      19403.54  151315          0
# 4         5      3  2010      1     1     0      21827.90  151315          0
# ...     ...    ...   ...    ...   ...   ...           ...     ...        ...
# 551474   28      6  2013     45    98     1           NaN  118221          0
# 551475    5      7  2013     45    98     1           NaN  118221          0
# 551476   12      7  2013     45    98     1           NaN  118221          0
# 551477   19      7  2013     45    98     1           NaN  118221          0
# 551478   26      7  2013     45    98     1           NaN  118221          0
#
#         Temperature  Fuel_Price         CPI  Unemployment         Differ
# 0             42.31       2.572  211.096358         8.106     522010-1-1
# 1             38.51       2.548  211.242170         8.106    1222010-1-1
# 2             39.93       2.514  211.289143         8.106    1922010-1-1
# 3             46.63       2.561  211.319643         8.106    2622010-1-1
# 4             46.50       2.625  211.350143         8.106     532010-1-1
# ...             ...         ...         ...           ...            ...
# 551474        76.05       3.639         NaN           NaN  2862013-45-98
# 551475        77.50       3.614         NaN           NaN   572013-45-98
# 551476        79.37       3.614         NaN           NaN  1272013-45-98
# 551477        82.84       3.737         NaN           NaN  1972013-45-98
# 551478        76.06       3.804         NaN           NaN  2672013-45-98
#
# [551479 rows x 14 columns]

# %%
# ML function for model 2:

def RandomForest(df,null_columns,lable):

    df1 = df.drop(columns = null_columns)

    # separating null columns:
    df1_null = df1[df1[lable].isnull()]
    df1_null.reset_index(drop = True, inplace = True)

    # separating not null columns:
    df1_notnull = df1[df1[lable].notnull()]
    df1_notnull.reset_index(drop = True, inplace = True)

    # choosing x and y value from notnull  dataframe:
    x = df1_notnull.drop(columns = [lable,"Differ"])
    y = df1_notnull[lable]

    #train test splitting:
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

    model = RandomForestRegressor().fit(x_train, y_train)
    y_pred = model.predict(x_test)

    # evaluating the model:
    mse = mean_squared_error(y_pred, y_test)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_pred, y_test)
    r2 = r2_score(y_pred, y_test)

    metrics = {"Mean Squared Error":mse,
               "Root Mean Squared Error": rmse,
               "Mean Absolute Error": mae,
               "R2 Score": r2}
    print(metrics)

    # predicting the null values for null dataframe
    test_data = df1_null.drop(columns = [lable, "Differ"])
    y_pred_null_df = model.predict(test_data)

    df1_null[lable] = pd.DataFrame(y_pred_null_df)

    df_result = pd.concat([df1_null,df1_notnull], axis = 0, ignore_index=True)

    return df_result

# %%
# CPI
df_m2_cpi = RandomForest(df5_m2,["Weekly_Sales","Unemployment"],"CPI")
# Out:
# {'Mean Squared Error': 5.64372753369711e-26, 'Root Mean Squared Error': 2.375653075197873e-13, 'Mean Absolute Error': 2.0348328739118085e-13, 'R2 Score': 1.0}

# %%
df_m2_CPI = df5_m2.drop(columns = ["CPI"])

# %%
df_m2_C = pd.merge(df_m2_CPI, df_m2_cpi[["CPI","Differ"]],on = "Differ", how = "inner")

# %%
# Unemployment:
df_m2_unemp = RandomForest(df_m2_C, ["Weekly_Sales"],"Unemployment")
# Out:
# {'Mean Squared Error': 9.020981874208739e-28, 'Root Mean Squared Error': 3.0034949432633874e-14, 'Mean Absolute Error': 2.163381573270918e-14, 'R2 Score': 1.0}

# %%
df_m2_UNEMP = df_m2_C.drop(columns = ["Unemployment"])

# %%
df_m2_CU = pd.merge(df_m2_UNEMP,df_m2_unemp[["Unemployment","Differ"]], on = "Differ", how = "inner")

# %%
# weekly sales:
df_m2_ws = RandomForest(df_m2_CU,[],"Weekly_Sales")
# Out:
# {'Mean Squared Error': 11224114.489940025, 'Root Mean Squared Error': 3350.2409599818375, 'Mean Absolute Error': 1367.1135039241817, 'R2 Score': 0.9775416543685156}

# %%
df_m2_CUW = df_m2_ws.copy()

# %%
# Creating a customer column by using weekly sales and cpi
df_m2_CUW["Customer"] = df_m2_CUW["Weekly_Sales"] / df_m2_CUW["CPI"]

# %%
df_m2_CUW
# Out:
#         Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0         2     11  2012      1     1     0    27383.3630  151315          0
# 1         9     11  2012      1     1     0    19995.8914  151315          0
# 2        16     11  2012      1     1     0    19940.4798  151315          0
# 3        23     11  2012      1     1     0    19604.1475  151315          1
# 4        30     11  2012      1     1     0    38886.9241  151315          0
# ...     ...    ...   ...    ...   ...   ...           ...     ...        ...
# 551474   28      9  2012     45    98     1      508.3700  118221          0
# 551475    5     10  2012     45    98     1      628.1000  118221          0
# 551476   12     10  2012     45    98     1     1061.0200  118221          0
# 551477   19     10  2012     45    98     1      760.0100  118221          0
# 551478   26     10  2012     45    98     1     1076.8000  118221          0
#
#         Temperature  Fuel_Price          Differ         CPI  Unemployment  \
# 0             55.32       3.386     2112012-1-1  223.462779         6.573
# 1             61.24       3.314     9112012-1-1  223.481307         6.573
# 2             52.92       3.252    16112012-1-1  223.512911         6.573
# 3             56.23       3.211    23112012-1-1  223.561947         6.573
# 4             52.34       3.207    30112012-1-1  223.610984         6.573
# ...             ...         ...             ...         ...           ...
# 551474        64.88       3.997   2892012-45-98  192.013558         8.684
# 551475        64.89       3.985   5102012-45-98  192.170412         8.667
# 551476        54.47       4.000  12102012-45-98  192.327265         8.667
# 551477        56.47       3.969  19102012-45-98  192.330854         8.667
# 551478        58.85       3.882  26102012-45-98  192.308899         8.667
#
#           Customer
# 0       122.541047
# 1        89.474559
# 2        89.213996
# 3        87.690001
# 4       173.904356
# ...            ...
# 551474    2.647573
# 551475    3.268453
# 551476    5.516743
# 551477    3.951576
# 551478    5.599325
#
# [551479 rows x 15 columns]

# %%
#df_m2_CUW.to_csv("Final_M2.csv",index = False)

# %%
df_m2_CUW.isnull().sum()
# Out:
# Day             0
# Month           0
# Year            0
# Store           0
# Dept            0
# Type            0
# Weekly_Sales    0
# Size            0
# IsHoliday       0
# Temperature     0
# Fuel_Price      0
# Differ          0
# CPI             0
# Unemployment    0
# Customer        0
# dtype: int64

# %%
df_M2 = pd.merge(df_m2_CU,df_m2_CUW[["Customer","Differ"]], on = "Differ", how = "inner")

# %%
#df_M2.to_csv("Final_Model2.csv",index = False)

# %%
# Separating null columns :
df_M2_null = df_M2[df_M2["Weekly_Sales"].isnull()]
df_M2_null.reset_index(drop = True, inplace = True)

# separating not null columns :
df_M2_notnull = df_M2[df_M2["Weekly_Sales"].notnull()]
df_M2_notnull.reset_index(drop = True, inplace = True)

# choosing x and y value from not null df:
x = df_M2_notnull.drop(columns =["Weekly_Sales", "Differ"])
y = df_M2_notnull["Weekly_Sales"]

# train test splitting:
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state  = 42)

# fitting with model
model2 = RandomForestRegressor().fit(x_train, y_train)
y_pred = model2.predict(x_test)

# evaluating the model:
mse = mean_squared_error(y_pred, y_test)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_pred, y_test)
r2 = r2_score(y_pred, y_test)

metrics = {"Mean Squared Error": mse,
           "Root Mean Squared Error": rmse,
           "Mean Absolute Error": mae, 
           "R2 Score": r2}

print(metrics)
# Out:
# {'Mean Squared Error': 41563.59351863525, 'Root Mean Squared Error': 203.87151227828582, 'Mean Absolute Error': 20.000458907939965, 'R2 Score': 0.9999187137755653}

# %%
d2 = pd.read_csv(r"C:\Users\ramya\Final_Model2.csv")
d2.head()
# Out:
#    Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0    5      2  2010      1     1     0      24924.50  151315          0
# 1   12      2  2010      1     1     0      46039.49  151315          1
# 2   19      2  2010      1     1     0      41595.55  151315          0
# 3   26      2  2010      1     1     0      19403.54  151315          0
# 4    5      3  2010      1     1     0      21827.90  151315          0
#
#    Temperature  Fuel_Price       Differ         CPI  Unemployment    Customer
# 0        42.31       2.572   522010-1-1  211.096358         8.106  118.071672
# 1        38.51       2.548  1222010-1-1  211.242170         8.106  217.946493
# 2        39.93       2.514  1922010-1-1  211.289143         8.106  196.865534
# 3        46.63       2.561  2622010-1-1  211.319643         8.106   91.820806
# 4        46.50       2.625   532010-1-1  211.350143         8.106  103.278378

# %%
y_pred2 = model2.predict(np.array([[5,2,2010,1,1,0,151315,0,42.31,2.572,211.096358,8.106,118.071672]]))
y_pred2[0]
# Out:
# 24929.740999999995

# %%
#with open(r"Final_ML_Model_2.pkl", "wb") as b:
    #pickle.dump(model2,b)

# %%
with open(r"Final_ML_Model_1.pkl", "rb") as a:
    pred_model_1 = pickle.load(a)

# %%
with open(r"Final_ML_Model_2.pkl","rb") as b:
    pred_model_2 = pickle.load(b)

# %%
df_M2.columns
# Out:
# Index(['Day', 'Month', 'Year', 'Store', 'Dept', 'Type', 'Weekly_Sales', 'Size',
#        'IsHoliday', 'Temperature', 'Fuel_Price', 'Differ', 'CPI',
#        'Unemployment', 'Customer'],
#       dtype='object')

# %%
y_pred1 = pred_model_1.predict(np.array([[5,2,2010,1,1,1,151315,0,42.31,2.6,7046.9,6618.9,166.9,16055.8,4671.9,211.1,8.1,9]]))
y_pred1[0]
# Out:
# 1901.0445000000002

# %% [markdown]
# ## Model for effects of MarkDown on Holiday weeks

# %%
df_m3 = pd.read_csv(r"C:\Users\ramya\Final_M1.csv")
df_m3.head()
# Out:
#    Day  Month  Year  Store  Dept  Type  Weekly_Sales    Size  IsHoliday  \
# 0    2     11  2012      1     1     0    27179.7256  151315          0
# 1    9     11  2012      1     1     0    24269.6853  151315          0
# 2   16     11  2012      1     1     0    19999.6773  151315          0
# 3   23     11  2012      1     1     0    23115.9782  151315          1
# 4   30     11  2012      1     1     0    56902.4252  151315          0
#
#    Temperature  Fuel_Price        Differ  MarkDown1   MarkDown2  MarkDown3  \
# 0        55.32       3.386   2112012-1-1    6766.44   5147.7000      50.82
# 1        61.24       3.314   9112012-1-1   11421.32   3370.8900      40.28
# 2        52.92       3.252  16112012-1-1    9696.28    292.1000     103.78
# 3        56.23       3.211  23112012-1-1     883.59      4.1700   74910.32
# 4        52.34       3.207  30112012-1-1    2460.03  20984.3795    3838.35
#
#    MarkDown4  MarkDown5         CPI  Unemployment    Customer
# 0    3639.90    2737.42  223.462779         6.573  121.629766
# 1    4646.79    6154.16  223.481307         6.573  108.598279
# 2    1133.15    6612.69  223.512911         6.573   89.478846
# 3     209.91     303.32  223.561947         6.573  103.398537
# 4     150.57    6966.34  223.610984         6.573  254.470617

# %%
df_H = df_m3[df_m3["IsHoliday"] == 1]
df_H.reset_index(drop = True, inplace = True)

df_NH = df_m3[df_m3["IsHoliday"] == 0]
df_NH.reset_index(drop = True, inplace = True)

# %%
df_m3.groupby("IsHoliday")["MarkDown1"].mean()
# Out:
# IsHoliday
# 0     6622.816482
# 1    11164.778885
# Name: MarkDown1, dtype: float64

# %%
df_m3.groupby("IsHoliday")["MarkDown2"].mean()
# Out:
# IsHoliday
# 0    2392.281407
# 1    9519.423898
# Name: MarkDown2, dtype: float64

# %%
df_m3.groupby("IsHoliday")["MarkDown3"].mean()
# Out:
# IsHoliday
# 0      352.892428
# 1    14822.652354
# Name: MarkDown3, dtype: float64

# %%
df_m3.groupby("IsHoliday")["MarkDown4"].mean()
# Out:
# IsHoliday
# 0    3028.40054
# 1    6681.47833
# Name: MarkDown4, dtype: float64

# %%
df_m3.groupby("IsHoliday")["MarkDown5"].mean()
# Out:
# IsHoliday
# 0    4869.637882
# 1    3725.278253
# Name: MarkDown5, dtype: float64

# %%
# Function for MarkDown by RandomForestRegressor

def MarkdownPrediction(df, lable):
    # choosing x and y value:
    x = df.drop(columns = [lable, "Differ"])
    y = df[lable]

    # train test splitting
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

    model = RandomForestRegressor().fit(x_train, y_train)
    y_pred = model.predict(x_test)

    #Evaluating the model:
    mse = mean_squared_error(y_pred, y_test)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_pred, y_test)
    r2 = r2_score(y_pred,y_test)

    metrics = {"Mean Squared Error": mse,
               "Root Mean Squared Error": rmse,
               "Mean Absolute Error": mae, 
               "R2 Score": r2}

    print(metrics)

    #if lable == "MarkDown1":
        #with open(r"Markdown_1.pkl","wb") as m1:
            #pickle.dump(model,m1)

    #elif lable == "MarkDown2":
        #with open(r"Markdown_2.pkl", "wb") as m2:
            #pickle.dump(model,m2)

    #elif lable == "MarkDown3":
        #with open(r"MarkDown_3.pkl", "wb") as m3:
            #pickle.dump(model, m3)

    #elif lable == "MarkDown4":
        #with open(r"Markdown_4.pkl", "wb") as m4:
            #pickle.dump(model, m4)

    #elif lable == "MarkDown5":
        #with open(r"Markdown_5.pkl", "wb") as m5:
            #pickle.load(model, m5)

# %%
df_H_m1 = MarkdownPrediction(df_H, "MarkDown1")
# Out:
# {'Mean Squared Error': 9.394301457091243e-22, 'Root Mean Squared Error': 3.065012472583308e-11, 'Mean Absolute Error': 1.4535923369301922e-11, 'R2 Score': 1.0}

# %%
df_H_m2 = MarkdownPrediction(df_H, "MarkDown2")
# Out:
# {'Mean Squared Error': 6.631118309625713e-22, 'Root Mean Squared Error': 2.575095786495274e-11, 'Mean Absolute Error': 1.0455867220385604e-11, 'R2 Score': 1.0}

# %%
df_H_m3 = MarkdownPrediction(df_H, "MarkDown3")
# Out:
# {'Mean Squared Error': 2.105461368457772e-21, 'Root Mean Squared Error': 4.588530667280945e-11, 'Mean Absolute Error': 1.767102170191179e-11, 'R2 Score': 1.0}

# %%
df_H_m4 = MarkdownPrediction(df_H, "MarkDown4")
# Out:
# {'Mean Squared Error': 0.01229109148844335, 'Root Mean Squared Error': 0.11086519511750904, 'Mean Absolute Error': 0.008580643306123386, 'R2 Score': 0.9999999999020084}

# %%
df_H_m5 = MarkdownPrediction(df_H, "MarkDown5")
# Out:
# {'Mean Squared Error': 5.142157309574084e-23, 'Root Mean Squared Error': 7.1708837039615165e-12, 'Mean Absolute Error': 4.3931053894063026e-12, 'R2 Score': 1.0}

# %%
with open(r"C:\Users\ramya\Markdown_1.pkl", "rb") as rm1:
    pred_m1 = pickle.load(rm1)

# %%
y_pred1 = pred_m1.predict(np.array([[12,2,2010,6,36,0,897.4775,202505,1,40.57,2.548,5182.2173,278.62,18521.4332,7279.8994,212.770042,7.259,4.218063]]))
y_pred1[0]
# Out:
# 31481.537911999956

# %%
with open(r"C:\Users\ramya\Markdown_2.pkl", "rb") as rm2:
    pred_m2 = pickle.load(rm2)

# %%
y_pred2 = pred_m1.predict(np.array([[12,2,2010,6,36,0,897.4775,202505,1,40.57,2.548,11341.7602,278.62,18521.4332,7279.8994,212.770042,7.259,4.218063]]))
y_pred2[0]
# Out:
# 12913.655224999971

# %%
with open(r"C:\Users\ramya\Markdown_3.pkl", "rb") as rm3:
    pred_m3 = pickle.load(rm3)

# %%
y_pred3 = pred_m1.predict(np.array([[12,2,2010,6,36,0,897.4775,202505,1,40.57,2.548,11341.7602,5182.2173,18521.4332,7279.8994,212.770042,7.259,4.218063]]))
y_pred3[0]
# Out:
# 12913.655224999971

# %%
with open(r"C:\Users\ramya\Markdown_4.pkl", "rb") as rm4:
    pred_m4 = pickle.load(rm4)

# %%
y_pred4 = pred_m4.predict(np.array([[12,2,2010,6,36,0,897.4775,202505,1,40.57,2.548,11341.7602,5182.2173,278.62,7279.8994,212.770042,7.259,4.218063]]))
y_pred4[0]
# Out:
# 14423.287949999987

# %%
with open(r"C:\Users\ramya\Markdown_5.pkl", "rb") as rm5:
    pred_m5 = pickle.load(rm5)

# %%
y_pred5 = pred_m5.predict(np.array([[12,2,2010,6,36,0,897.4775,202505,1,40.57,2.548,11341.7602,5182.2173,278.62,18521.4332,212.770042,7.259,4.218063]]))
y_pred5[0]
# Out:
# 7176.752446999998
